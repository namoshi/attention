# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np
from sklearn.decomposition import PCA
import random
import cv2

# %%
# デバイスの設定
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# ハイパーパラメータの設定
num_epochs = 100
batch_size = 128
learning_rate = 0.001
momentum = 0.9

# CIFAR-10データセットの準備
transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32, padding=4),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
trainloader = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)
testloader = DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Using device: cuda

# %%
# Self-Attention層の定義
class SelfAttention(nn.Module):
    def __init__(self, in_channels):
        super(SelfAttention, self).__init__()
        self.query = nn.Conv2d(in_channels, in_channels // 8, kernel_size=1)
        self.key = nn.Conv2d(in_channels, in_channels // 8, kernel_size=1)
        self.value = nn.Conv2d(in_channels, in_channels, kernel_size=1)
        self.gamma = nn.Parameter(torch.zeros(1))  # Attention weight
        self.softmax = nn.Softmax(dim=-1)

    def forward(self, x):
        batch_size, C, height, width = x.size()
        proj_query = self.query(x).view(batch_size, -1, height * width).permute(0, 2, 1)  # B x (H*W) x C'
        proj_key = self.key(x).view(batch_size, -1, height * width)  # B x C' x (H*W)
        energy = torch.bmm(proj_query, proj_key)  # batch matrix multiplication: B x (H*W) x (H*W)
        attention = self.softmax(energy)  # B x (H*W) x (H*W)
        proj_value = self.value(x).view(batch_size, -1, height * width)  # B x C x (H*W)

        out = torch.bmm(proj_value, attention.permute(0, 2, 1)).view(batch_size, C, height, width)  # B x C x H x W

        return self.gamma * out + x, attention

# CNNモデルの定義
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
#        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
#        self.relu3 = nn.ReLU()
#        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.attention = SelfAttention(64)  # Self-Attention層を追加
        self.fc1 = nn.Linear(64 * 8 * 8, 256)
        self.relu4 = nn.ReLU()
        self.fc2 = nn.Linear(256, 10)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
#        x = self.pool3(self.relu3(self.conv3(x)))
        x, attention_map = self.attention(x)  # Self-Attention層を通過
        x = x.view(-1, 64 * 8 * 8)
        x = self.relu4(self.fc1(x))
        x = self.fc2(x)
        return x, attention_map  # アテンションマップを返すように変更

    def get_features(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
#        x = self.pool3(self.relu3(self.conv3(x)))
        x, _ = self.attention(x)
        x = x.view(-1, 64 * 8 * 8)
        x = self.relu4(self.fc1(x))
        return x

# %%
# モデルのインスタンス化
net = Net().to(device)

# 損失関数と最適化関数の定義
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum)

# 学習の記録用リスト
train_losses = []
train_accuracies = []
test_losses = []
test_accuracies = []

# 学習ループ
for epoch in range(num_epochs):
    net.train()
    running_loss = 0.0
    correct_train = 0
    total_train = 0
    for i, data in enumerate(trainloader, 0):
        inputs, labels = data[0].to(device), data[1].to(device)

        optimizer.zero_grad()

        outputs, _ = net(inputs)  # アテンションマップはここでは使用しない
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        _, predicted = torch.max(outputs.data, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

    train_loss = running_loss / len(trainloader)
    train_accuracy = 100 * correct_train / total_train
    train_losses.append(train_loss)
    train_accuracies.append(train_accuracy)
    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.2f}%')

    # テストフェーズ
    net.eval()
    test_loss = 0.0
    correct_test = 0
    total_test = 0
    with torch.no_grad():
        for data in testloader:
            images, labels = data[0].to(device), data[1].to(device)
            outputs, _ = net(images)  # アテンションマップはここでは使用しない
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total_test += labels.size(0)
            correct_test += (predicted == labels).sum().item()

    test_loss = test_loss / len(testloader)
    test_accuracy = 100 * correct_test / total_test
    test_losses.append(test_loss)
    test_accuracies.append(test_accuracy)
    print(f'Epoch [{epoch+1}/{num_epochs}], Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%')

print('Finished Training')
# Out:
# Epoch [1/100], Train Loss: 2.2301, Train Accuracy: 19.13%
# Epoch [1/100], Test Loss: 2.0713, Test Accuracy: 28.22%
# Epoch [2/100], Train Loss: 1.9828, Train Accuracy: 28.82%
# Epoch [2/100], Test Loss: 1.8560, Test Accuracy: 34.27%
# Epoch [3/100], Train Loss: 1.8604, Train Accuracy: 33.21%
# Epoch [3/100], Test Loss: 1.7419, Test Accuracy: 38.04%
# Epoch [4/100], Train Loss: 1.7568, Train Accuracy: 37.05%
# Epoch [4/100], Test Loss: 1.6448, Test Accuracy: 41.25%
# Epoch [5/100], Train Loss: 1.6608, Train Accuracy: 40.06%
# Epoch [5/100], Test Loss: 1.5324, Test Accuracy: 44.82%
# Epoch [6/100], Train Loss: 1.5863, Train Accuracy: 42.28%
# Epoch [6/100], Test Loss: 1.4664, Test Accuracy: 47.31%
# Epoch [7/100], Train Loss: 1.5355, Train Accuracy: 44.19%
# Epoch [7/100], Test Loss: 1.4426, Test Accuracy: 47.25%
# Epoch [8/100], Train Loss: 1.4969, Train Accuracy: 45.86%
# Epoch [8/100], Test Loss: 1.3996, Test Accuracy: 49.58%
# Epoch [9/100], Train Loss: 1.4675, Train Accuracy: 46.74%
# Epoch [9/100], Test Loss: 1.3657, Test Accuracy: 50.26%
# Epoch [10/100], Train Loss: 1.4375, Train Accuracy: 47.94%
# Epoch [10/100], Test Loss: 1.3220, Test Accuracy: 52.01%
# Epoch [11/100], Train Loss: 1.4100, Train Accuracy: 49.35%
# Epoch [11/100], Test Loss: 1.3080, Test Accuracy: 53.10%
# Epoch [12/100], Train Loss: 1.3847, Train Accuracy: 50.25%
# Epoch [12/100], Test Loss: 1.2735, Test Accuracy: 54.34%
# Epoch [13/100], Train Loss: 1.3639, Train Accuracy: 51.13%
# Epoch [13/100], Test Loss: 1.2500, Test Accuracy: 54.84%
# Epoch [14/100], Train Loss: 1.3389, Train Accuracy: 52.09%
# Epoch [14/100], Test Loss: 1.2211, Test Accuracy: 56.60%
# Epoch [15/100], Train Loss: 1.3149, Train Accuracy: 53.01%
# Epoch [15/100], Test Loss: 1.2040, Test Accuracy: 57.40%
# Epoch [16/100], Train Loss: 1.2941, Train Accuracy: 53.62%
# Epoch [16/100], Test Loss: 1.1863, Test Accuracy: 57.69%
# Epoch [17/100], Train Loss: 1.2739, Train Accuracy: 54.54%
# Epoch [17/100], Test Loss: 1.1676, Test Accuracy: 58.55%
# Epoch [18/100], Train Loss: 1.2523, Train Accuracy: 55.45%
# Epoch [18/100], Test Loss: 1.1447, Test Accuracy: 59.25%
# Epoch [19/100], Train Loss: 1.2298, Train Accuracy: 55.86%
# Epoch [19/100], Test Loss: 1.1313, Test Accuracy: 59.83%
# Epoch [20/100], Train Loss: 1.2145, Train Accuracy: 56.62%
# Epoch [20/100], Test Loss: 1.1209, Test Accuracy: 60.03%
# Epoch [21/100], Train Loss: 1.1944, Train Accuracy: 57.54%
# Epoch [21/100], Test Loss: 1.0976, Test Accuracy: 60.72%
# Epoch [22/100], Train Loss: 1.1767, Train Accuracy: 58.26%
# Epoch [22/100], Test Loss: 1.0759, Test Accuracy: 61.78%
# Epoch [23/100], Train Loss: 1.1542, Train Accuracy: 58.88%
# Epoch [23/100], Test Loss: 1.0538, Test Accuracy: 62.82%
# Epoch [24/100], Train Loss: 1.1400, Train Accuracy: 59.44%
# Epoch [24/100], Test Loss: 1.0422, Test Accuracy: 63.56%
# Epoch [25/100], Train Loss: 1.1213, Train Accuracy: 60.51%
# Epoch [25/100], Test Loss: 1.0368, Test Accuracy: 63.11%
# Epoch [26/100], Train Loss: 1.1034, Train Accuracy: 60.94%
# Epoch [26/100], Test Loss: 1.0209, Test Accuracy: 64.49%
# Epoch [27/100], Train Loss: 1.0918, Train Accuracy: 61.41%
# Epoch [27/100], Test Loss: 0.9910, Test Accuracy: 65.18%
# Epoch [28/100], Train Loss: 1.0735, Train Accuracy: 62.09%
# Epoch [28/100], Test Loss: 0.9804, Test Accuracy: 65.46%
# Epoch [29/100], Train Loss: 1.0608, Train Accuracy: 62.62%
# Epoch [29/100], Test Loss: 0.9723, Test Accuracy: 66.12%
# Epoch [30/100], Train Loss: 1.0409, Train Accuracy: 63.30%
# Epoch [30/100], Test Loss: 0.9582, Test Accuracy: 66.31%
# Epoch [31/100], Train Loss: 1.0268, Train Accuracy: 63.70%
# Epoch [31/100], Test Loss: 0.9648, Test Accuracy: 65.71%
# Epoch [32/100], Train Loss: 1.0197, Train Accuracy: 64.16%
# Epoch [32/100], Test Loss: 0.9402, Test Accuracy: 67.04%
# Epoch [33/100], Train Loss: 1.0024, Train Accuracy: 64.78%
# Epoch [33/100], Test Loss: 0.9421, Test Accuracy: 67.13%
# Epoch [34/100], Train Loss: 0.9949, Train Accuracy: 64.97%
# Epoch [34/100], Test Loss: 0.9342, Test Accuracy: 67.00%
# Epoch [35/100], Train Loss: 0.9811, Train Accuracy: 65.64%
# Epoch [35/100], Test Loss: 0.9079, Test Accuracy: 68.57%
# Epoch [36/100], Train Loss: 0.9694, Train Accuracy: 66.02%
# Epoch [36/100], Test Loss: 0.8948, Test Accuracy: 68.63%
# Epoch [37/100], Train Loss: 0.9611, Train Accuracy: 66.23%
# Epoch [37/100], Test Loss: 0.8992, Test Accuracy: 68.41%
# Epoch [38/100], Train Loss: 0.9484, Train Accuracy: 66.47%
# Epoch [38/100], Test Loss: 0.8839, Test Accuracy: 69.34%
# Epoch [39/100], Train Loss: 0.9380, Train Accuracy: 67.12%
# Epoch [39/100], Test Loss: 0.8755, Test Accuracy: 69.56%
# Epoch [40/100], Train Loss: 0.9295, Train Accuracy: 67.31%
# Epoch [40/100], Test Loss: 0.8824, Test Accuracy: 68.98%
# Epoch [41/100], Train Loss: 0.9207, Train Accuracy: 67.53%
# Epoch [41/100], Test Loss: 0.8586, Test Accuracy: 70.33%
# Epoch [42/100], Train Loss: 0.9046, Train Accuracy: 68.19%
# Epoch [42/100], Test Loss: 0.8503, Test Accuracy: 70.50%
# Epoch [43/100], Train Loss: 0.8998, Train Accuracy: 68.60%
# Epoch [43/100], Test Loss: 0.8510, Test Accuracy: 70.47%
# Epoch [44/100], Train Loss: 0.8921, Train Accuracy: 68.90%
# Epoch [44/100], Test Loss: 0.8442, Test Accuracy: 70.73%
# Epoch [45/100], Train Loss: 0.8813, Train Accuracy: 69.15%
# Epoch [45/100], Test Loss: 0.8360, Test Accuracy: 70.77%
# Epoch [46/100], Train Loss: 0.8730, Train Accuracy: 69.48%
# Epoch [46/100], Test Loss: 0.8206, Test Accuracy: 71.76%
# Epoch [47/100], Train Loss: 0.8651, Train Accuracy: 69.68%
# Epoch [47/100], Test Loss: 0.8255, Test Accuracy: 71.35%
# Epoch [48/100], Train Loss: 0.8545, Train Accuracy: 70.36%
# Epoch [48/100], Test Loss: 0.8126, Test Accuracy: 72.38%
# Epoch [49/100], Train Loss: 0.8507, Train Accuracy: 70.13%
# Epoch [49/100], Test Loss: 0.8112, Test Accuracy: 71.85%
# Epoch [50/100], Train Loss: 0.8419, Train Accuracy: 70.60%
# Epoch [50/100], Test Loss: 0.7975, Test Accuracy: 72.31%
# Epoch [51/100], Train Loss: 0.8346, Train Accuracy: 70.79%
# Epoch [51/100], Test Loss: 0.7909, Test Accuracy: 72.69%
# Epoch [52/100], Train Loss: 0.8301, Train Accuracy: 70.91%
# Epoch [52/100], Test Loss: 0.7876, Test Accuracy: 72.48%
# Epoch [53/100], Train Loss: 0.8207, Train Accuracy: 71.36%
# Epoch [53/100], Test Loss: 0.7786, Test Accuracy: 73.09%
# Epoch [54/100], Train Loss: 0.8070, Train Accuracy: 71.87%
# Epoch [54/100], Test Loss: 0.7744, Test Accuracy: 73.26%
# Epoch [55/100], Train Loss: 0.8074, Train Accuracy: 71.85%
# Epoch [55/100], Test Loss: 0.7783, Test Accuracy: 72.98%
# Epoch [56/100], Train Loss: 0.8002, Train Accuracy: 72.02%
# Epoch [56/100], Test Loss: 0.7715, Test Accuracy: 73.56%
# Epoch [57/100], Train Loss: 0.7963, Train Accuracy: 72.15%
# Epoch [57/100], Test Loss: 0.7839, Test Accuracy: 72.94%
# Epoch [58/100], Train Loss: 0.7856, Train Accuracy: 72.43%
# Epoch [58/100], Test Loss: 0.7693, Test Accuracy: 73.41%
# Epoch [59/100], Train Loss: 0.7812, Train Accuracy: 72.66%
# Epoch [59/100], Test Loss: 0.7616, Test Accuracy: 73.78%
# Epoch [60/100], Train Loss: 0.7759, Train Accuracy: 72.77%
# Epoch [60/100], Test Loss: 0.7514, Test Accuracy: 74.08%
# Epoch [61/100], Train Loss: 0.7659, Train Accuracy: 73.12%
# Epoch [61/100], Test Loss: 0.7536, Test Accuracy: 74.11%
# Epoch [62/100], Train Loss: 0.7627, Train Accuracy: 73.31%
# Epoch [62/100], Test Loss: 0.7397, Test Accuracy: 74.61%
# Epoch [63/100], Train Loss: 0.7537, Train Accuracy: 73.70%
# Epoch [63/100], Test Loss: 0.7414, Test Accuracy: 74.47%
# Epoch [64/100], Train Loss: 0.7455, Train Accuracy: 73.75%
# Epoch [64/100], Test Loss: 0.7365, Test Accuracy: 74.73%
# Epoch [65/100], Train Loss: 0.7445, Train Accuracy: 74.00%
# Epoch [65/100], Test Loss: 0.7366, Test Accuracy: 74.49%
# Epoch [66/100], Train Loss: 0.7365, Train Accuracy: 74.40%
# Epoch [66/100], Test Loss: 0.7311, Test Accuracy: 74.53%
# Epoch [67/100], Train Loss: 0.7260, Train Accuracy: 74.72%
# Epoch [67/100], Test Loss: 0.7286, Test Accuracy: 74.81%
# Epoch [68/100], Train Loss: 0.7259, Train Accuracy: 74.51%
# Epoch [68/100], Test Loss: 0.7239, Test Accuracy: 74.99%
# Epoch [69/100], Train Loss: 0.7215, Train Accuracy: 74.71%
# Epoch [69/100], Test Loss: 0.7233, Test Accuracy: 74.90%
# Epoch [70/100], Train Loss: 0.7158, Train Accuracy: 75.14%
# Epoch [70/100], Test Loss: 0.7148, Test Accuracy: 75.47%
# Epoch [71/100], Train Loss: 0.7095, Train Accuracy: 75.11%
# Epoch [71/100], Test Loss: 0.7112, Test Accuracy: 75.53%
# Epoch [72/100], Train Loss: 0.7058, Train Accuracy: 75.37%
# Epoch [72/100], Test Loss: 0.6949, Test Accuracy: 76.13%
# Epoch [73/100], Train Loss: 0.7025, Train Accuracy: 75.35%
# Epoch [73/100], Test Loss: 0.7034, Test Accuracy: 76.03%
# Epoch [74/100], Train Loss: 0.6961, Train Accuracy: 75.80%
# Epoch [74/100], Test Loss: 0.7088, Test Accuracy: 75.36%
# Epoch [75/100], Train Loss: 0.6953, Train Accuracy: 75.61%
# Epoch [75/100], Test Loss: 0.6925, Test Accuracy: 76.41%
# Epoch [76/100], Train Loss: 0.6873, Train Accuracy: 75.96%
# Epoch [76/100], Test Loss: 0.7048, Test Accuracy: 75.76%
# Epoch [77/100], Train Loss: 0.6839, Train Accuracy: 76.06%
# Epoch [77/100], Test Loss: 0.6882, Test Accuracy: 76.29%
# Epoch [78/100], Train Loss: 0.6827, Train Accuracy: 76.05%
# Epoch [78/100], Test Loss: 0.6929, Test Accuracy: 76.25%
# Epoch [79/100], Train Loss: 0.6764, Train Accuracy: 76.45%
# Epoch [79/100], Test Loss: 0.6987, Test Accuracy: 75.81%
# Epoch [80/100], Train Loss: 0.6728, Train Accuracy: 76.73%
# Epoch [80/100], Test Loss: 0.6866, Test Accuracy: 76.51%
# Epoch [81/100], Train Loss: 0.6648, Train Accuracy: 76.74%
# Epoch [81/100], Test Loss: 0.6807, Test Accuracy: 76.61%
# Epoch [82/100], Train Loss: 0.6620, Train Accuracy: 76.85%
# Epoch [82/100], Test Loss: 0.6833, Test Accuracy: 76.64%
# Epoch [83/100], Train Loss: 0.6582, Train Accuracy: 77.00%
# Epoch [83/100], Test Loss: 0.6674, Test Accuracy: 77.38%
# Epoch [84/100], Train Loss: 0.6592, Train Accuracy: 77.07%
# Epoch [84/100], Test Loss: 0.6881, Test Accuracy: 76.28%
# Epoch [85/100], Train Loss: 0.6530, Train Accuracy: 77.02%
# Epoch [85/100], Test Loss: 0.6705, Test Accuracy: 77.07%
# Epoch [86/100], Train Loss: 0.6487, Train Accuracy: 77.33%
# Epoch [86/100], Test Loss: 0.6747, Test Accuracy: 76.75%
# Epoch [87/100], Train Loss: 0.6470, Train Accuracy: 77.34%
# Epoch [87/100], Test Loss: 0.6751, Test Accuracy: 77.26%
# Epoch [88/100], Train Loss: 0.6388, Train Accuracy: 77.66%
# Epoch [88/100], Test Loss: 0.6760, Test Accuracy: 76.63%
# Epoch [89/100], Train Loss: 0.6379, Train Accuracy: 77.67%
# Epoch [89/100], Test Loss: 0.6640, Test Accuracy: 77.30%
# Epoch [90/100], Train Loss: 0.6308, Train Accuracy: 78.05%
# Epoch [90/100], Test Loss: 0.6521, Test Accuracy: 77.65%
# Epoch [91/100], Train Loss: 0.6284, Train Accuracy: 78.00%
# Epoch [91/100], Test Loss: 0.6676, Test Accuracy: 77.09%
# Epoch [92/100], Train Loss: 0.6293, Train Accuracy: 77.95%
# Epoch [92/100], Test Loss: 0.6644, Test Accuracy: 77.52%
# Epoch [93/100], Train Loss: 0.6237, Train Accuracy: 78.19%
# Epoch [93/100], Test Loss: 0.6638, Test Accuracy: 77.38%
# Epoch [94/100], Train Loss: 0.6156, Train Accuracy: 78.57%
# Epoch [94/100], Test Loss: 0.6675, Test Accuracy: 77.09%
# Epoch [95/100], Train Loss: 0.6168, Train Accuracy: 78.30%
# Epoch [95/100], Test Loss: 0.6511, Test Accuracy: 77.72%
# Epoch [96/100], Train Loss: 0.6096, Train Accuracy: 78.80%
# Epoch [96/100], Test Loss: 0.6635, Test Accuracy: 77.19%
# Epoch [97/100], Train Loss: 0.6134, Train Accuracy: 78.52%
# Epoch [97/100], Test Loss: 0.6453, Test Accuracy: 78.12%
# Epoch [98/100], Train Loss: 0.6096, Train Accuracy: 78.89%
# Epoch [98/100], Test Loss: 0.6498, Test Accuracy: 78.00%
# Epoch [99/100], Train Loss: 0.6027, Train Accuracy: 78.96%
# Epoch [99/100], Test Loss: 0.6457, Test Accuracy: 77.32%
# Epoch [100/100], Train Loss: 0.6012, Train Accuracy: 79.00%
# Epoch [100/100], Test Loss: 0.6415, Test Accuracy: 78.15%
# Finished Training

# %%
# 学習曲線のプロット (変更なし)
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.plot(test_losses, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Testing Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_accuracies, label='Train Accuracy')
plt.plot(test_accuracies, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Training and Testing Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# 中間層の特徴ベクトルの可視化
net.eval()
all_features = []
all_labels = []
with torch.no_grad():
    for i, (images, labels) in enumerate(testloader):
#        if i >= 10:  # 最初の10バッチのみ使用 (計算量を抑えるため)
#            break
        images = images.to(device)
        features = net.get_features(images).cpu().numpy()
        all_features.append(features)
        all_labels.append(labels.cpu().numpy())

all_features = np.concatenate(all_features, axis=0)
all_labels = np.concatenate(all_labels, axis=0)

pca = PCA(n_components=2)
principal_components = pca.fit_transform(all_features)

# 色使いの変更: 'viridis' を 'tab10' または 'Set1' などに変更
plt.figure(figsize=(8, 6))
colors = plt.cm.get_cmap('tab10', len(classes)) # または plt.cm.get_cmap('Set1', len(classes)) など

for i in range(len(classes)):
    indices = np.where(all_labels == i)[0]
    plt.scatter(principal_components[indices, 0], principal_components[indices, 1],
                label=classes[i], alpha=0.6, c=[colors(i)])
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Intermediate Layer Features')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_37594/2339931689.py:22: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap('tab10', len(classes)) # または plt.cm.get_cmap('Set1', len(classes)) など

# %%
# 学習後のアテンションの可視化 (修正)
def visualize_attention_on_image(model, image, original_image, class_names):
    model.eval()
    with torch.no_grad():
        # 入力画像をデバイスに移動し、バッチ次元を追加
        image_tensor = image.unsqueeze(0).to(device)
        output, attention_map = model(image_tensor)
        _, predicted_idx = torch.max(output, 1)
        predicted_class = class_names[predicted_idx.item()]

        # アテンションマップをCPUとNumPy配列に移動
        attention_map = attention_map.squeeze(0).cpu().numpy()
        # アテンションマップのサイズは (H*W) x (H*W)
        # H, W はプーリング後の特徴マップのサイズ (4x4)
        # attention_map を 4x4 のグリッドとして可視化するためにreshape
        attn_map = attention_map.reshape(8, 8, 8, 8).mean(axis=(2, 3)) # 各4x4のブロックの平均を取る

        # ヒートマップのサイズを入力画像のサイズに合わせる
        original_height, original_width = original_image.shape[1], original_image.shape[2]
        attn_map_resized = cv2.resize(attn_map, (original_width, original_height))

        # 0から1の範囲に正規化
        attn_map_normalized = (attn_map_resized - np.min(attn_map_resized)) / (np.max(attn_map_resized) - np.min(attn_map_resized) + 1e-8) # ゼロ除算回避
        heatmap = cv2.applyColorMap(np.uint8(255 * attn_map_normalized), cv2.COLORMAP_JET)
        heatmap_rgb = cv2.cvtColor(heatmap, cv2.COLOR_BGR2RGB)

        # オリジナル画像をRGBに変換
        original_image_rgb = (original_image.permute(1, 2, 0).cpu().numpy() * 0.5 + 0.5) * 255
        original_image_rgb = original_image_rgb.astype(np.uint8)

        # サイズが一致しているか確認 (デバッグ用)
        if original_image_rgb.shape[:2] != heatmap_rgb.shape[:2] or original_image_rgb.shape[2] != 3 or heatmap_rgb.shape[2] != 3:
            print(f"Error: Shape mismatch before overlaying.")
            print(f"Original Image Shape: {original_image_rgb.shape}")
            print(f"Heatmap Shape: {heatmap_rgb.shape}")
            return

        # ヒートマップをオーバーレイ
        alpha = 0.5  # 透明度
        overlay = cv2.addWeighted(original_image_rgb, 1 - alpha, heatmap_rgb, alpha, 0)

        plt.figure(figsize=(6, 6))
        plt.imshow(overlay)
        plt.title(f'Attention Map Overlay (Predicted: {predicted_class})')
        plt.axis('off')
        plt.show()

# %%
# テストデータからランダムなサンプルを選択
num_samples_to_visualize = 5
indices = random.sample(range(len(testset)), num_samples_to_visualize)
for index in indices:
    img, label = testset[index]
    original_img = img.clone() # 可視化用にオリジナルのテンソルを保持
    class_name = classes[label]
    print(f"Visualizing attention for sample with label: {class_name}")
    visualize_attention_on_image(net, img, original_img, classes)
# Out:
# Visualizing attention for sample with label: plane
# Visualizing attention for sample with label: truck
# Visualizing attention for sample with label: deer
# Visualizing attention for sample with label: truck
# Visualizing attention for sample with label: horse
