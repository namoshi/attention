# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np
from sklearn.decomposition import PCA
import random
import cv2

# %%
# デバイスの設定
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# ハイパーパラメータの設定
num_epochs = 100
batch_size = 128
learning_rate = 0.001
momentum = 0.9

# CIFAR-10データセットの準備
transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32, padding=4),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
trainloader = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)
testloader = DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Using device: cuda

# %%
# Self-Attention層の定義
class SelfAttention(nn.Module):
    def __init__(self, in_channels):
        super(SelfAttention, self).__init__()
        self.query = nn.Conv2d(in_channels, in_channels // 8, kernel_size=1)
        self.key = nn.Conv2d(in_channels, in_channels // 8, kernel_size=1)
        self.value = nn.Conv2d(in_channels, in_channels, kernel_size=1)
        self.gamma = nn.Parameter(torch.zeros(1))  # Attention weight
        self.softmax = nn.Softmax(dim=-1)

    def forward(self, x):
        batch_size, C, height, width = x.size()
        proj_query = self.query(x).view(batch_size, -1, height * width).permute(0, 2, 1)  # B x (H*W) x C'
        proj_key = self.key(x).view(batch_size, -1, height * width)  # B x C' x (H*W)
        energy = torch.bmm(proj_query, proj_key)  # batch matrix multiplication: B x (H*W) x (H*W)
        attention = self.softmax(energy)  # B x (H*W) x (H*W)
        proj_value = self.value(x).view(batch_size, -1, height * width)  # B x C x (H*W)

        out = torch.bmm(proj_value, attention.permute(0, 2, 1)).view(batch_size, C, height, width)  # B x C x H x W

        return self.gamma * out + x, attention

# CNNモデルの定義
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.relu3 = nn.ReLU()
        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.attention = SelfAttention(128)  # Self-Attention層を追加
        self.fc1 = nn.Linear(128 * 4 * 4, 512)
        self.relu4 = nn.ReLU()
        self.fc2 = nn.Linear(512, 10)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = self.pool3(self.relu3(self.conv3(x)))
        x, attention_map = self.attention(x)  # Self-Attention層を通過
        x = x.view(-1, 128 * 4 * 4)
        x = self.relu4(self.fc1(x))
        x = self.fc2(x)
        return x, attention_map  # アテンションマップを返すように変更

    def get_features(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = self.pool3(self.relu3(self.conv3(x)))
        x, _ = self.attention(x)
        x = x.view(-1, 128 * 4 * 4)
        x = self.relu4(self.fc1(x))
        return x

# %%
# モデルのインスタンス化
net = Net().to(device)

# 損失関数と最適化関数の定義
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum)

# 学習の記録用リスト
train_losses = []
train_accuracies = []
test_losses = []
test_accuracies = []

# 学習ループ
for epoch in range(num_epochs):
    net.train()
    running_loss = 0.0
    correct_train = 0
    total_train = 0
    for i, data in enumerate(trainloader, 0):
        inputs, labels = data[0].to(device), data[1].to(device)

        optimizer.zero_grad()

        outputs, _ = net(inputs)  # アテンションマップはここでは使用しない
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        _, predicted = torch.max(outputs.data, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

    train_loss = running_loss / len(trainloader)
    train_accuracy = 100 * correct_train / total_train
    train_losses.append(train_loss)
    train_accuracies.append(train_accuracy)
    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.2f}%')

    # テストフェーズ
    net.eval()
    test_loss = 0.0
    correct_test = 0
    total_test = 0
    with torch.no_grad():
        for data in testloader:
            images, labels = data[0].to(device), data[1].to(device)
            outputs, _ = net(images)  # アテンションマップはここでは使用しない
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total_test += labels.size(0)
            correct_test += (predicted == labels).sum().item()

    test_loss = test_loss / len(testloader)
    test_accuracy = 100 * correct_test / total_test
    test_losses.append(test_loss)
    test_accuracies.append(test_accuracy)
    print(f'Epoch [{epoch+1}/{num_epochs}], Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%')

print('Finished Training')
# Out:
# Epoch [1/100], Train Loss: 2.2948, Train Accuracy: 10.88%
# Epoch [1/100], Test Loss: 2.2765, Test Accuracy: 17.87%
# Epoch [2/100], Train Loss: 2.1977, Train Accuracy: 21.16%
# Epoch [2/100], Test Loss: 2.0679, Test Accuracy: 26.58%
# Epoch [3/100], Train Loss: 2.0228, Train Accuracy: 26.87%
# Epoch [3/100], Test Loss: 1.9271, Test Accuracy: 30.54%
# Epoch [4/100], Train Loss: 1.9258, Train Accuracy: 30.28%
# Epoch [4/100], Test Loss: 1.8345, Test Accuracy: 34.19%
# Epoch [5/100], Train Loss: 1.8481, Train Accuracy: 33.17%
# Epoch [5/100], Test Loss: 1.7428, Test Accuracy: 37.34%
# Epoch [6/100], Train Loss: 1.7572, Train Accuracy: 36.20%
# Epoch [6/100], Test Loss: 1.6289, Test Accuracy: 41.31%
# Epoch [7/100], Train Loss: 1.6682, Train Accuracy: 39.12%
# Epoch [7/100], Test Loss: 1.5661, Test Accuracy: 43.44%
# Epoch [8/100], Train Loss: 1.6122, Train Accuracy: 41.05%
# Epoch [8/100], Test Loss: 1.5329, Test Accuracy: 43.86%
# Epoch [9/100], Train Loss: 1.5600, Train Accuracy: 43.12%
# Epoch [9/100], Test Loss: 1.4872, Test Accuracy: 45.96%
# Epoch [10/100], Train Loss: 1.5251, Train Accuracy: 44.68%
# Epoch [10/100], Test Loss: 1.4457, Test Accuracy: 46.75%
# Epoch [11/100], Train Loss: 1.4878, Train Accuracy: 45.92%
# Epoch [11/100], Test Loss: 1.3961, Test Accuracy: 49.12%
# Epoch [12/100], Train Loss: 1.4569, Train Accuracy: 46.84%
# Epoch [12/100], Test Loss: 1.3657, Test Accuracy: 51.17%
# Epoch [13/100], Train Loss: 1.4261, Train Accuracy: 48.09%
# Epoch [13/100], Test Loss: 1.3624, Test Accuracy: 51.06%
# Epoch [14/100], Train Loss: 1.4014, Train Accuracy: 49.36%
# Epoch [14/100], Test Loss: 1.3181, Test Accuracy: 53.12%
# Epoch [15/100], Train Loss: 1.3774, Train Accuracy: 50.25%
# Epoch [15/100], Test Loss: 1.2781, Test Accuracy: 55.11%
# Epoch [16/100], Train Loss: 1.3488, Train Accuracy: 51.57%
# Epoch [16/100], Test Loss: 1.2773, Test Accuracy: 54.07%
# Epoch [17/100], Train Loss: 1.3261, Train Accuracy: 52.45%
# Epoch [17/100], Test Loss: 1.2378, Test Accuracy: 55.64%
# Epoch [18/100], Train Loss: 1.3053, Train Accuracy: 53.32%
# Epoch [18/100], Test Loss: 1.2371, Test Accuracy: 55.95%
# Epoch [19/100], Train Loss: 1.2811, Train Accuracy: 54.17%
# Epoch [19/100], Test Loss: 1.1911, Test Accuracy: 57.47%
# Epoch [20/100], Train Loss: 1.2542, Train Accuracy: 55.23%
# Epoch [20/100], Test Loss: 1.1626, Test Accuracy: 58.25%
# Epoch [21/100], Train Loss: 1.2315, Train Accuracy: 56.26%
# Epoch [21/100], Test Loss: 1.1584, Test Accuracy: 58.67%
# Epoch [22/100], Train Loss: 1.2090, Train Accuracy: 56.75%
# Epoch [22/100], Test Loss: 1.1285, Test Accuracy: 60.07%
# Epoch [23/100], Train Loss: 1.1917, Train Accuracy: 57.52%
# Epoch [23/100], Test Loss: 1.1296, Test Accuracy: 59.73%
# Epoch [24/100], Train Loss: 1.1696, Train Accuracy: 58.42%
# Epoch [24/100], Test Loss: 1.0820, Test Accuracy: 61.73%
# Epoch [25/100], Train Loss: 1.1477, Train Accuracy: 59.38%
# Epoch [25/100], Test Loss: 1.0576, Test Accuracy: 62.83%
# Epoch [26/100], Train Loss: 1.1331, Train Accuracy: 60.03%
# Epoch [26/100], Test Loss: 1.0569, Test Accuracy: 62.99%
# Epoch [27/100], Train Loss: 1.1063, Train Accuracy: 60.95%
# Epoch [27/100], Test Loss: 1.0256, Test Accuracy: 64.06%
# Epoch [28/100], Train Loss: 1.0929, Train Accuracy: 61.42%
# Epoch [28/100], Test Loss: 1.0307, Test Accuracy: 63.91%
# Epoch [29/100], Train Loss: 1.0749, Train Accuracy: 62.01%
# Epoch [29/100], Test Loss: 0.9865, Test Accuracy: 65.50%
# Epoch [30/100], Train Loss: 1.0532, Train Accuracy: 62.88%
# Epoch [30/100], Test Loss: 0.9853, Test Accuracy: 65.35%
# Epoch [31/100], Train Loss: 1.0387, Train Accuracy: 63.42%
# Epoch [31/100], Test Loss: 0.9887, Test Accuracy: 65.07%
# Epoch [32/100], Train Loss: 1.0270, Train Accuracy: 64.14%
# Epoch [32/100], Test Loss: 0.9511, Test Accuracy: 66.95%
# Epoch [33/100], Train Loss: 1.0076, Train Accuracy: 64.64%
# Epoch [33/100], Test Loss: 0.9329, Test Accuracy: 67.52%
# Epoch [34/100], Train Loss: 0.9912, Train Accuracy: 65.09%
# Epoch [34/100], Test Loss: 0.9408, Test Accuracy: 67.13%
# Epoch [35/100], Train Loss: 0.9775, Train Accuracy: 65.64%
# Epoch [35/100], Test Loss: 0.9296, Test Accuracy: 67.53%
# Epoch [36/100], Train Loss: 0.9622, Train Accuracy: 66.18%
# Epoch [36/100], Test Loss: 0.9147, Test Accuracy: 67.89%
# Epoch [37/100], Train Loss: 0.9464, Train Accuracy: 66.93%
# Epoch [37/100], Test Loss: 0.8885, Test Accuracy: 69.35%
# Epoch [38/100], Train Loss: 0.9373, Train Accuracy: 67.19%
# Epoch [38/100], Test Loss: 0.8798, Test Accuracy: 69.24%
# Epoch [39/100], Train Loss: 0.9242, Train Accuracy: 67.74%
# Epoch [39/100], Test Loss: 0.8670, Test Accuracy: 70.28%
# Epoch [40/100], Train Loss: 0.9051, Train Accuracy: 68.37%
# Epoch [40/100], Test Loss: 0.8673, Test Accuracy: 69.98%
# Epoch [41/100], Train Loss: 0.8941, Train Accuracy: 68.53%
# Epoch [41/100], Test Loss: 0.8485, Test Accuracy: 70.71%
# Epoch [42/100], Train Loss: 0.8766, Train Accuracy: 69.35%
# Epoch [42/100], Test Loss: 0.8445, Test Accuracy: 70.67%
# Epoch [43/100], Train Loss: 0.8673, Train Accuracy: 69.65%
# Epoch [43/100], Test Loss: 0.8381, Test Accuracy: 70.91%
# Epoch [44/100], Train Loss: 0.8582, Train Accuracy: 70.07%
# Epoch [44/100], Test Loss: 0.8144, Test Accuracy: 71.87%
# Epoch [45/100], Train Loss: 0.8486, Train Accuracy: 70.30%
# Epoch [45/100], Test Loss: 0.8093, Test Accuracy: 71.76%
# Epoch [46/100], Train Loss: 0.8357, Train Accuracy: 70.78%
# Epoch [46/100], Test Loss: 0.8003, Test Accuracy: 72.39%
# Epoch [47/100], Train Loss: 0.8270, Train Accuracy: 71.03%
# Epoch [47/100], Test Loss: 0.7873, Test Accuracy: 73.06%
# Epoch [48/100], Train Loss: 0.8117, Train Accuracy: 71.67%
# Epoch [48/100], Test Loss: 0.7757, Test Accuracy: 73.13%
# Epoch [49/100], Train Loss: 0.8056, Train Accuracy: 71.87%
# Epoch [49/100], Test Loss: 0.7862, Test Accuracy: 72.80%
# Epoch [50/100], Train Loss: 0.7921, Train Accuracy: 72.43%
# Epoch [50/100], Test Loss: 0.7660, Test Accuracy: 73.66%
# Epoch [51/100], Train Loss: 0.7866, Train Accuracy: 72.40%
# Epoch [51/100], Test Loss: 0.7587, Test Accuracy: 73.81%
# Epoch [52/100], Train Loss: 0.7736, Train Accuracy: 73.10%
# Epoch [52/100], Test Loss: 0.7674, Test Accuracy: 73.20%
# Epoch [53/100], Train Loss: 0.7651, Train Accuracy: 73.38%
# Epoch [53/100], Test Loss: 0.7475, Test Accuracy: 74.37%
# Epoch [54/100], Train Loss: 0.7573, Train Accuracy: 73.53%
# Epoch [54/100], Test Loss: 0.7357, Test Accuracy: 74.68%
# Epoch [55/100], Train Loss: 0.7490, Train Accuracy: 73.74%
# Epoch [55/100], Test Loss: 0.7338, Test Accuracy: 74.78%
# Epoch [56/100], Train Loss: 0.7379, Train Accuracy: 74.22%
# Epoch [56/100], Test Loss: 0.7273, Test Accuracy: 74.97%
# Epoch [57/100], Train Loss: 0.7306, Train Accuracy: 74.41%
# Epoch [57/100], Test Loss: 0.7282, Test Accuracy: 75.02%
# Epoch [58/100], Train Loss: 0.7253, Train Accuracy: 74.56%
# Epoch [58/100], Test Loss: 0.7149, Test Accuracy: 75.38%
# Epoch [59/100], Train Loss: 0.7160, Train Accuracy: 75.10%
# Epoch [59/100], Test Loss: 0.7197, Test Accuracy: 75.18%
# Epoch [60/100], Train Loss: 0.7079, Train Accuracy: 75.43%
# Epoch [60/100], Test Loss: 0.7116, Test Accuracy: 75.46%
# Epoch [61/100], Train Loss: 0.6993, Train Accuracy: 75.71%
# Epoch [61/100], Test Loss: 0.6970, Test Accuracy: 75.81%
# Epoch [62/100], Train Loss: 0.6925, Train Accuracy: 75.76%
# Epoch [62/100], Test Loss: 0.7030, Test Accuracy: 75.91%
# Epoch [63/100], Train Loss: 0.6830, Train Accuracy: 76.19%
# Epoch [63/100], Test Loss: 0.6999, Test Accuracy: 75.71%
# Epoch [64/100], Train Loss: 0.6765, Train Accuracy: 76.21%
# Epoch [64/100], Test Loss: 0.6816, Test Accuracy: 76.76%
# Epoch [65/100], Train Loss: 0.6716, Train Accuracy: 76.61%
# Epoch [65/100], Test Loss: 0.6787, Test Accuracy: 76.76%
# Epoch [66/100], Train Loss: 0.6623, Train Accuracy: 77.01%
# Epoch [66/100], Test Loss: 0.6830, Test Accuracy: 76.61%
# Epoch [67/100], Train Loss: 0.6551, Train Accuracy: 77.15%
# Epoch [67/100], Test Loss: 0.6710, Test Accuracy: 76.61%
# Epoch [68/100], Train Loss: 0.6517, Train Accuracy: 77.20%
# Epoch [68/100], Test Loss: 0.6971, Test Accuracy: 76.27%
# Epoch [69/100], Train Loss: 0.6429, Train Accuracy: 77.43%
# Epoch [69/100], Test Loss: 0.6661, Test Accuracy: 77.34%
# Epoch [70/100], Train Loss: 0.6426, Train Accuracy: 77.51%
# Epoch [70/100], Test Loss: 0.6526, Test Accuracy: 77.61%
# Epoch [71/100], Train Loss: 0.6359, Train Accuracy: 77.75%
# Epoch [71/100], Test Loss: 0.6659, Test Accuracy: 77.48%
# Epoch [72/100], Train Loss: 0.6257, Train Accuracy: 78.16%
# Epoch [72/100], Test Loss: 0.6519, Test Accuracy: 77.43%
# Epoch [73/100], Train Loss: 0.6226, Train Accuracy: 78.21%
# Epoch [73/100], Test Loss: 0.6993, Test Accuracy: 75.87%
# Epoch [74/100], Train Loss: 0.6130, Train Accuracy: 78.47%
# Epoch [74/100], Test Loss: 0.6418, Test Accuracy: 77.96%
# Epoch [75/100], Train Loss: 0.6079, Train Accuracy: 78.69%
# Epoch [75/100], Test Loss: 0.6341, Test Accuracy: 78.34%
# Epoch [76/100], Train Loss: 0.6026, Train Accuracy: 78.96%
# Epoch [76/100], Test Loss: 0.6425, Test Accuracy: 78.09%
# Epoch [77/100], Train Loss: 0.5914, Train Accuracy: 79.18%
# Epoch [77/100], Test Loss: 0.6322, Test Accuracy: 78.41%
# Epoch [78/100], Train Loss: 0.5942, Train Accuracy: 79.22%
# Epoch [78/100], Test Loss: 0.6332, Test Accuracy: 78.48%
# Epoch [79/100], Train Loss: 0.5857, Train Accuracy: 79.52%
# Epoch [79/100], Test Loss: 0.6390, Test Accuracy: 78.43%
# Epoch [80/100], Train Loss: 0.5793, Train Accuracy: 79.89%
# Epoch [80/100], Test Loss: 0.6199, Test Accuracy: 79.02%
# Epoch [81/100], Train Loss: 0.5822, Train Accuracy: 79.67%
# Epoch [81/100], Test Loss: 0.6336, Test Accuracy: 78.24%
# Epoch [82/100], Train Loss: 0.5748, Train Accuracy: 79.77%
# Epoch [82/100], Test Loss: 0.6207, Test Accuracy: 78.70%
# Epoch [83/100], Train Loss: 0.5663, Train Accuracy: 80.18%
# Epoch [83/100], Test Loss: 0.6216, Test Accuracy: 78.80%
# Epoch [84/100], Train Loss: 0.5632, Train Accuracy: 80.47%
# Epoch [84/100], Test Loss: 0.6339, Test Accuracy: 78.74%
# Epoch [85/100], Train Loss: 0.5555, Train Accuracy: 80.75%
# Epoch [85/100], Test Loss: 0.6421, Test Accuracy: 78.49%
# Epoch [86/100], Train Loss: 0.5557, Train Accuracy: 80.55%
# Epoch [86/100], Test Loss: 0.6200, Test Accuracy: 78.87%
# Epoch [87/100], Train Loss: 0.5489, Train Accuracy: 80.78%
# Epoch [87/100], Test Loss: 0.6188, Test Accuracy: 78.87%
# Epoch [88/100], Train Loss: 0.5448, Train Accuracy: 81.11%
# Epoch [88/100], Test Loss: 0.6272, Test Accuracy: 78.33%
# Epoch [89/100], Train Loss: 0.5394, Train Accuracy: 81.27%
# Epoch [89/100], Test Loss: 0.6001, Test Accuracy: 79.55%
# Epoch [90/100], Train Loss: 0.5315, Train Accuracy: 81.53%
# Epoch [90/100], Test Loss: 0.6095, Test Accuracy: 79.17%
# Epoch [91/100], Train Loss: 0.5309, Train Accuracy: 81.42%
# Epoch [91/100], Test Loss: 0.6123, Test Accuracy: 79.49%
# Epoch [92/100], Train Loss: 0.5272, Train Accuracy: 81.65%
# Epoch [92/100], Test Loss: 0.6034, Test Accuracy: 79.47%
# Epoch [93/100], Train Loss: 0.5175, Train Accuracy: 81.88%
# Epoch [93/100], Test Loss: 0.6122, Test Accuracy: 79.30%
# Epoch [94/100], Train Loss: 0.5154, Train Accuracy: 82.02%
# Epoch [94/100], Test Loss: 0.5976, Test Accuracy: 79.79%
# Epoch [95/100], Train Loss: 0.5139, Train Accuracy: 81.93%
# Epoch [95/100], Test Loss: 0.6164, Test Accuracy: 79.25%
# Epoch [96/100], Train Loss: 0.5047, Train Accuracy: 82.31%
# Epoch [96/100], Test Loss: 0.6029, Test Accuracy: 79.71%
# Epoch [97/100], Train Loss: 0.5002, Train Accuracy: 82.51%
# Epoch [97/100], Test Loss: 0.5995, Test Accuracy: 79.68%
# Epoch [98/100], Train Loss: 0.4980, Train Accuracy: 82.63%
# Epoch [98/100], Test Loss: 0.5935, Test Accuracy: 79.78%
# Epoch [99/100], Train Loss: 0.4929, Train Accuracy: 82.71%
# Epoch [99/100], Test Loss: 0.6038, Test Accuracy: 79.89%
# Epoch [100/100], Train Loss: 0.4930, Train Accuracy: 82.86%
# Epoch [100/100], Test Loss: 0.5907, Test Accuracy: 79.98%
# Finished Training

# %%
# 学習曲線のプロット (変更なし)
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.plot(test_losses, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Testing Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_accuracies, label='Train Accuracy')
plt.plot(test_accuracies, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Training and Testing Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# 中間層の特徴ベクトルの可視化
net.eval()
all_features = []
all_labels = []
with torch.no_grad():
    for i, (images, labels) in enumerate(testloader):
#        if i >= 10:  # 最初の10バッチのみ使用 (計算量を抑えるため)
#            break
        images = images.to(device)
        features = net.get_features(images).cpu().numpy()
        all_features.append(features)
        all_labels.append(labels.cpu().numpy())

all_features = np.concatenate(all_features, axis=0)
all_labels = np.concatenate(all_labels, axis=0)

pca = PCA(n_components=2)
principal_components = pca.fit_transform(all_features)

# 色使いの変更: 'viridis' を 'tab10' または 'Set1' などに変更
plt.figure(figsize=(8, 6))
colors = plt.cm.get_cmap('tab10', len(classes)) # または plt.cm.get_cmap('Set1', len(classes)) など

for i in range(len(classes)):
    indices = np.where(all_labels == i)[0]
    plt.scatter(principal_components[indices, 0], principal_components[indices, 1],
                label=classes[i], alpha=0.6, c=[colors(i)])
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Intermediate Layer Features')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_30652/2339931689.py:22: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap('tab10', len(classes)) # または plt.cm.get_cmap('Set1', len(classes)) など

# %%
# 学習後のアテンションの可視化 (修正)
def visualize_attention_on_image(model, image, original_image, class_names):
    model.eval()
    with torch.no_grad():
        # 入力画像をデバイスに移動し、バッチ次元を追加
        image_tensor = image.unsqueeze(0).to(device)
        output, attention_map = model(image_tensor)
        _, predicted_idx = torch.max(output, 1)
        predicted_class = class_names[predicted_idx.item()]

        # アテンションマップをCPUとNumPy配列に移動
        attention_map = attention_map.squeeze(0).cpu().numpy()
        # アテンションマップのサイズは (H*W) x (H*W)
        # H, W はプーリング後の特徴マップのサイズ (4x4)
        # attention_map を 4x4 のグリッドとして可視化するためにreshape
        attn_map = attention_map.reshape(4, 4, 4, 4).mean(axis=(2, 3)) # 各4x4のブロックの平均を取る

        # ヒートマップのサイズを入力画像のサイズに合わせる
        original_height, original_width = original_image.shape[1], original_image.shape[2]
        attn_map_resized = cv2.resize(attn_map, (original_width, original_height))

        # 0から1の範囲に正規化
        attn_map_normalized = (attn_map_resized - np.min(attn_map_resized)) / (np.max(attn_map_resized) - np.min(attn_map_resized) + 1e-8) # ゼロ除算回避
        heatmap = cv2.applyColorMap(np.uint8(255 * attn_map_normalized), cv2.COLORMAP_JET)
        heatmap_rgb = cv2.cvtColor(heatmap, cv2.COLOR_BGR2RGB)

        # オリジナル画像をRGBに変換
        original_image_rgb = (original_image.permute(1, 2, 0).cpu().numpy() * 0.5 + 0.5) * 255
        original_image_rgb = original_image_rgb.astype(np.uint8)

        # サイズが一致しているか確認 (デバッグ用)
        if original_image_rgb.shape[:2] != heatmap_rgb.shape[:2] or original_image_rgb.shape[2] != 3 or heatmap_rgb.shape[2] != 3:
            print(f"Error: Shape mismatch before overlaying.")
            print(f"Original Image Shape: {original_image_rgb.shape}")
            print(f"Heatmap Shape: {heatmap_rgb.shape}")
            return

        # ヒートマップをオーバーレイ
        alpha = 0.5  # 透明度
        overlay = cv2.addWeighted(original_image_rgb, 1 - alpha, heatmap_rgb, alpha, 0)

        plt.figure(figsize=(6, 6))
        plt.imshow(overlay)
        plt.title(f'Attention Map Overlay (Predicted: {predicted_class})')
        plt.axis('off')
        plt.show()

# %%
# テストデータからランダムなサンプルを選択
num_samples_to_visualize = 5
indices = random.sample(range(len(testset)), num_samples_to_visualize)
for index in indices:
    img, label = testset[index]
    original_img = img.clone() # 可視化用にオリジナルのテンソルを保持
    class_name = classes[label]
    print(f"Visualizing attention for sample with label: {class_name}")
    visualize_attention_on_image(net, img, original_img, classes)
# Out:
# Visualizing attention for sample with label: deer
# Visualizing attention for sample with label: plane
# Visualizing attention for sample with label: car
# Visualizing attention for sample with label: truck
# Visualizing attention for sample with label: dog
