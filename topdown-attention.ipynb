# %% [markdown]
# # Top Down Attention

# %%
import os
import cv2

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np
from sklearn.decomposition import PCA
import random

from dataloader import DatasetLoader
from model.attention_cnn import Net
from plot.loss import plot_loss
from plot.vis import visualize_attention_on_image

import sys

# %%
ex_name='w_attention'
apply_attention = True
save_dir = f'/home/kurita/GitHub/attention/output/{ex_name}'
os.makedirs(save_dir, exist_ok=True)
dataset_dir = '/home/kurita/GitHub/attention/data'

# %%
# デバイスの設定
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# ハイパーパラメータの設定
num_epochs = 200
batch_size = 128
learning_rate = 0.001
momentum = 0.9

# CIFAR-10データセットの準備
transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32, padding=4),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
#trainset = DatasetLoader(root=dataset_dir, phase='train', transform=transform_train)
trainloader = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)
#testset = DatasetLoader(root=dataset_dir, phase='test', transform=transform_test)
testloader = DataLoader(testset, batch_size=batch_size, shuffle=True, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Using device: cuda

# %%
# モデルのインスタンス化
net = Net(apply_attention=apply_attention).to(device)

# 損失関数と最適化関数の定義
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum)

# 学習の記録用リスト
train_losses = []
train_accuracies = []
test_losses = []
test_accuracies = []

# 学習ループ
for epoch in range(num_epochs):
    net.train()
    running_loss = 0.0
    correct_train = 0
    total_train = 0
    for i, data in enumerate(trainloader, 0):
        inputs, labels = data[0].to(device), data[1].to(device)
        # inputs, labels = data['image'].to(device), data['label'].to(device)

        if (i == 0):
            print(f'Epoch {epoch+1}\n-------------------------------')
#        print('i=', i)

        optimizer.zero_grad()
#        print(inputs.shape, labels.shape)
        
        outputs = net(inputs)
#        print(outputs.shape)
        
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        _, predicted = torch.max(outputs.data, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

    train_loss = running_loss / len(trainloader)
    train_accuracy = 100 * correct_train / total_train
    train_losses.append(train_loss)
    train_accuracies.append(train_accuracy)
    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.2f}%')

    # テストフェーズ
    net.eval()
    test_loss = 0.0
    correct_test = 0
    total_test = 0
    with torch.no_grad():
        for i, data in enumerate(testloader):
            images, labels = data[0].to(device), data[1].to(device)
            # images, labels = data['image'].to(device), data['label'].to(device)

            outputs = net(images) # モデルの出力
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total_test += labels.size(0)
            correct_test += (predicted == labels).sum().item()

    test_loss = test_loss / len(testloader)
    test_accuracy = 100 * correct_test / total_test
    test_losses.append(test_loss)
    test_accuracies.append(test_accuracy)
    print(f'Epoch [{epoch+1}/{num_epochs}], Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%')

print('Finished Training')
plot_loss(os.path.join(save_dir, 'loss.png'), train_losses, test_losses, train_accuracies, test_accuracies)
# Out:
# Epoch 1
# -------------------------------
# Epoch [1/200], Train Loss: 2.2812, Train Accuracy: 16.76%
# Epoch [1/200], Test Loss: 2.2313, Test Accuracy: 23.38%
# Epoch 2
# -------------------------------
# Epoch [2/200], Train Loss: 2.1452, Train Accuracy: 23.84%
# Epoch [2/200], Test Loss: 2.0246, Test Accuracy: 28.24%
# Epoch 3
# -------------------------------
# Epoch [3/200], Train Loss: 1.9702, Train Accuracy: 29.33%
# Epoch [3/200], Test Loss: 1.8455, Test Accuracy: 34.78%
# Epoch 4
# -------------------------------
# Epoch [4/200], Train Loss: 1.8223, Train Accuracy: 34.14%
# Epoch [4/200], Test Loss: 1.6780, Test Accuracy: 40.49%
# Epoch 5
# -------------------------------
# Epoch [5/200], Train Loss: 1.6787, Train Accuracy: 38.47%
# Epoch [5/200], Test Loss: 1.5419, Test Accuracy: 44.20%
# Epoch 6
# -------------------------------
# Epoch [6/200], Train Loss: 1.5832, Train Accuracy: 41.39%
# Epoch [6/200], Test Loss: 1.4855, Test Accuracy: 46.28%
# Epoch 7
# -------------------------------
# Epoch [7/200], Train Loss: 1.5150, Train Accuracy: 44.23%
# Epoch [7/200], Test Loss: 1.4207, Test Accuracy: 48.44%
# Epoch 8
# -------------------------------
# Epoch [8/200], Train Loss: 1.4653, Train Accuracy: 46.27%
# Epoch [8/200], Test Loss: 1.3741, Test Accuracy: 49.94%
# Epoch 9
# -------------------------------
# Epoch [9/200], Train Loss: 1.4222, Train Accuracy: 47.96%
# Epoch [9/200], Test Loss: 1.3341, Test Accuracy: 51.63%
# Epoch 10
# -------------------------------
# Epoch [10/200], Train Loss: 1.3816, Train Accuracy: 49.43%
# Epoch [10/200], Test Loss: 1.2923, Test Accuracy: 53.13%
# Epoch 11
# -------------------------------
# Epoch [11/200], Train Loss: 1.3453, Train Accuracy: 50.77%
# Epoch [11/200], Test Loss: 1.2666, Test Accuracy: 53.84%
# Epoch 12
# -------------------------------
# Epoch [12/200], Train Loss: 1.3114, Train Accuracy: 52.07%
# Epoch [12/200], Test Loss: 1.2285, Test Accuracy: 54.84%
# Epoch 13
# -------------------------------
# Epoch [13/200], Train Loss: 1.2759, Train Accuracy: 53.37%
# Epoch [13/200], Test Loss: 1.1673, Test Accuracy: 57.87%
# Epoch 14
# -------------------------------
# Epoch [14/200], Train Loss: 1.2421, Train Accuracy: 54.85%
# Epoch [14/200], Test Loss: 1.1373, Test Accuracy: 59.07%
# Epoch 15
# -------------------------------
# Epoch [15/200], Train Loss: 1.2087, Train Accuracy: 56.25%
# Epoch [15/200], Test Loss: 1.1031, Test Accuracy: 59.94%
# Epoch 16
# -------------------------------
# Epoch [16/200], Train Loss: 1.1766, Train Accuracy: 57.53%
# Epoch [16/200], Test Loss: 1.0796, Test Accuracy: 60.94%
# Epoch 17
# -------------------------------
# Epoch [17/200], Train Loss: 1.1401, Train Accuracy: 58.65%
# Epoch [17/200], Test Loss: 1.0464, Test Accuracy: 62.59%
# Epoch 18
# -------------------------------
# Epoch [18/200], Train Loss: 1.1034, Train Accuracy: 60.09%
# Epoch [18/200], Test Loss: 1.0187, Test Accuracy: 63.54%
# Epoch 19
# -------------------------------
# Epoch [19/200], Train Loss: 1.0736, Train Accuracy: 61.32%
# Epoch [19/200], Test Loss: 0.9797, Test Accuracy: 65.24%
# Epoch 20
# -------------------------------
# Epoch [20/200], Train Loss: 1.0441, Train Accuracy: 62.59%
# Epoch [20/200], Test Loss: 0.9790, Test Accuracy: 64.62%
# Epoch 21
# -------------------------------
# Epoch [21/200], Train Loss: 1.0196, Train Accuracy: 63.19%
# Epoch [21/200], Test Loss: 0.9406, Test Accuracy: 66.60%
# Epoch 22
# -------------------------------
# Epoch [22/200], Train Loss: 0.9930, Train Accuracy: 64.27%
# Epoch [22/200], Test Loss: 0.9410, Test Accuracy: 66.05%
# Epoch 23
# -------------------------------
# Epoch [23/200], Train Loss: 0.9757, Train Accuracy: 64.99%
# Epoch [23/200], Test Loss: 0.9201, Test Accuracy: 67.86%
# Epoch 24
# -------------------------------
# Epoch [24/200], Train Loss: 0.9490, Train Accuracy: 65.97%
# Epoch [24/200], Test Loss: 0.8929, Test Accuracy: 68.08%
# Epoch 25
# -------------------------------
# Epoch [25/200], Train Loss: 0.9325, Train Accuracy: 66.45%
# Epoch [25/200], Test Loss: 0.8702, Test Accuracy: 69.15%
# Epoch 26
# -------------------------------
# Epoch [26/200], Train Loss: 0.9064, Train Accuracy: 67.51%
# Epoch [26/200], Test Loss: 0.8378, Test Accuracy: 70.20%
# Epoch 27
# -------------------------------
# Epoch [27/200], Train Loss: 0.8893, Train Accuracy: 68.12%
# Epoch [27/200], Test Loss: 0.8494, Test Accuracy: 70.24%
# Epoch 28
# -------------------------------
# Epoch [28/200], Train Loss: 0.8792, Train Accuracy: 68.52%
# Epoch [28/200], Test Loss: 0.8402, Test Accuracy: 70.61%
# Epoch 29
# -------------------------------
# Epoch [29/200], Train Loss: 0.8559, Train Accuracy: 69.45%
# Epoch [29/200], Test Loss: 0.8141, Test Accuracy: 71.04%
# Epoch 30
# -------------------------------
# Epoch [30/200], Train Loss: 0.8429, Train Accuracy: 69.82%
# Epoch [30/200], Test Loss: 0.8046, Test Accuracy: 71.48%
# Epoch 31
# -------------------------------
# Epoch [31/200], Train Loss: 0.8242, Train Accuracy: 70.81%
# Epoch [31/200], Test Loss: 0.7988, Test Accuracy: 71.86%
# Epoch 32
# -------------------------------
# Epoch [32/200], Train Loss: 0.8101, Train Accuracy: 71.17%
# Epoch [32/200], Test Loss: 0.8053, Test Accuracy: 71.86%
# Epoch 33
# -------------------------------
# Epoch [33/200], Train Loss: 0.7994, Train Accuracy: 71.47%
# Epoch [33/200], Test Loss: 0.7694, Test Accuracy: 73.49%
# Epoch 34
# -------------------------------
# Epoch [34/200], Train Loss: 0.7846, Train Accuracy: 72.03%
# Epoch [34/200], Test Loss: 0.8022, Test Accuracy: 72.10%
# Epoch 35
# -------------------------------
# Epoch [35/200], Train Loss: 0.7709, Train Accuracy: 72.67%
# Epoch [35/200], Test Loss: 0.7669, Test Accuracy: 73.00%
# Epoch 36
# -------------------------------
# Epoch [36/200], Train Loss: 0.7607, Train Accuracy: 72.87%
# Epoch [36/200], Test Loss: 0.7312, Test Accuracy: 74.42%
# Epoch 37
# -------------------------------
# Epoch [37/200], Train Loss: 0.7469, Train Accuracy: 73.25%
# Epoch [37/200], Test Loss: 0.7147, Test Accuracy: 75.09%
# Epoch 38
# -------------------------------
# Epoch [38/200], Train Loss: 0.7394, Train Accuracy: 73.78%
# Epoch [38/200], Test Loss: 0.7305, Test Accuracy: 74.62%
# Epoch 39
# -------------------------------
# Epoch [39/200], Train Loss: 0.7300, Train Accuracy: 73.97%
# Epoch [39/200], Test Loss: 0.7524, Test Accuracy: 74.03%
# Epoch 40
# -------------------------------
# Epoch [40/200], Train Loss: 0.7128, Train Accuracy: 74.67%
# Epoch [40/200], Test Loss: 0.7305, Test Accuracy: 75.16%
# Epoch 41
# -------------------------------
# Epoch [41/200], Train Loss: 0.7035, Train Accuracy: 75.01%
# Epoch [41/200], Test Loss: 0.6942, Test Accuracy: 75.42%
# Epoch 42
# -------------------------------
# Epoch [42/200], Train Loss: 0.6914, Train Accuracy: 75.49%
# Epoch [42/200], Test Loss: 0.7251, Test Accuracy: 74.76%
# Epoch 43
# -------------------------------
# Epoch [43/200], Train Loss: 0.6860, Train Accuracy: 75.66%
# Epoch [43/200], Test Loss: 0.6854, Test Accuracy: 76.33%
# Epoch 44
# -------------------------------
# Epoch [44/200], Train Loss: 0.6801, Train Accuracy: 75.87%
# Epoch [44/200], Test Loss: 0.6861, Test Accuracy: 75.81%
# Epoch 45
# -------------------------------
# Epoch [45/200], Train Loss: 0.6710, Train Accuracy: 76.16%
# Epoch [45/200], Test Loss: 0.6716, Test Accuracy: 76.40%
# Epoch 46
# -------------------------------
# Epoch [46/200], Train Loss: 0.6579, Train Accuracy: 76.62%
# Epoch [46/200], Test Loss: 0.6600, Test Accuracy: 76.94%
# Epoch 47
# -------------------------------
# Epoch [47/200], Train Loss: 0.6515, Train Accuracy: 76.94%
# Epoch [47/200], Test Loss: 0.6973, Test Accuracy: 75.36%
# Epoch 48
# -------------------------------
# Epoch [48/200], Train Loss: 0.6470, Train Accuracy: 77.03%
# Epoch [48/200], Test Loss: 0.6475, Test Accuracy: 77.32%
# Epoch 49
# -------------------------------
# Epoch [49/200], Train Loss: 0.6384, Train Accuracy: 77.49%
# Epoch [49/200], Test Loss: 0.6657, Test Accuracy: 76.95%
# Epoch 50
# -------------------------------
# Epoch [50/200], Train Loss: 0.6286, Train Accuracy: 77.88%
# Epoch [50/200], Test Loss: 0.6859, Test Accuracy: 75.96%
# Epoch 51
# -------------------------------
# Epoch [51/200], Train Loss: 0.6271, Train Accuracy: 77.90%
# Epoch [51/200], Test Loss: 0.6261, Test Accuracy: 78.31%
# Epoch 52
# -------------------------------
# Epoch [52/200], Train Loss: 0.6172, Train Accuracy: 78.10%
# Epoch [52/200], Test Loss: 0.6455, Test Accuracy: 78.13%
# Epoch 53
# -------------------------------
# Epoch [53/200], Train Loss: 0.6037, Train Accuracy: 78.76%
# Epoch [53/200], Test Loss: 0.6417, Test Accuracy: 77.75%
# Epoch 54
# -------------------------------
# Epoch [54/200], Train Loss: 0.5981, Train Accuracy: 78.73%
# Epoch [54/200], Test Loss: 0.6660, Test Accuracy: 77.08%
# Epoch 55
# -------------------------------
# Epoch [55/200], Train Loss: 0.5888, Train Accuracy: 79.15%
# Epoch [55/200], Test Loss: 0.6195, Test Accuracy: 78.51%
# Epoch 56
# -------------------------------
# Epoch [56/200], Train Loss: 0.5890, Train Accuracy: 79.10%
# Epoch [56/200], Test Loss: 0.6392, Test Accuracy: 77.95%
# Epoch 57
# -------------------------------
# Epoch [57/200], Train Loss: 0.5787, Train Accuracy: 79.70%
# Epoch [57/200], Test Loss: 0.6378, Test Accuracy: 78.45%
# Epoch 58
# -------------------------------
# Epoch [58/200], Train Loss: 0.5684, Train Accuracy: 79.79%
# Epoch [58/200], Test Loss: 0.6466, Test Accuracy: 78.13%
# Epoch 59
# -------------------------------
# Epoch [59/200], Train Loss: 0.5689, Train Accuracy: 79.76%
# Epoch [59/200], Test Loss: 0.6027, Test Accuracy: 79.13%
# Epoch 60
# -------------------------------
# Epoch [60/200], Train Loss: 0.5545, Train Accuracy: 80.31%
# Epoch [60/200], Test Loss: 0.6114, Test Accuracy: 78.79%
# Epoch 61
# -------------------------------
# Epoch [61/200], Train Loss: 0.5517, Train Accuracy: 80.39%
# Epoch [61/200], Test Loss: 0.6156, Test Accuracy: 78.80%
# Epoch 62
# -------------------------------
# Epoch [62/200], Train Loss: 0.5459, Train Accuracy: 80.46%
# Epoch [62/200], Test Loss: 0.6188, Test Accuracy: 78.82%
# Epoch 63
# -------------------------------
# Epoch [63/200], Train Loss: 0.5429, Train Accuracy: 80.77%
# Epoch [63/200], Test Loss: 0.6061, Test Accuracy: 79.42%
# Epoch 64
# -------------------------------
# Epoch [64/200], Train Loss: 0.5355, Train Accuracy: 81.01%
# Epoch [64/200], Test Loss: 0.6183, Test Accuracy: 78.73%
# Epoch 65
# -------------------------------
# Epoch [65/200], Train Loss: 0.5320, Train Accuracy: 81.16%
# Epoch [65/200], Test Loss: 0.6296, Test Accuracy: 78.68%
# Epoch 66
# -------------------------------
# Epoch [66/200], Train Loss: 0.5250, Train Accuracy: 81.41%
# Epoch [66/200], Test Loss: 0.6076, Test Accuracy: 79.54%
# Epoch 67
# -------------------------------
# Epoch [67/200], Train Loss: 0.5197, Train Accuracy: 81.63%
# Epoch [67/200], Test Loss: 0.6217, Test Accuracy: 78.87%
# Epoch 68
# -------------------------------
# Epoch [68/200], Train Loss: 0.5165, Train Accuracy: 81.63%
# Epoch [68/200], Test Loss: 0.6138, Test Accuracy: 79.19%
# Epoch 69
# -------------------------------
# Epoch [69/200], Train Loss: 0.5121, Train Accuracy: 81.88%
# Epoch [69/200], Test Loss: 0.6041, Test Accuracy: 79.44%
# Epoch 70
# -------------------------------
# Epoch [70/200], Train Loss: 0.5034, Train Accuracy: 82.10%
# Epoch [70/200], Test Loss: 0.6183, Test Accuracy: 79.27%
# Epoch 71
# -------------------------------
# Epoch [71/200], Train Loss: 0.4989, Train Accuracy: 82.32%
# Epoch [71/200], Test Loss: 0.6080, Test Accuracy: 79.54%
# Epoch 72
# -------------------------------
# Epoch [72/200], Train Loss: 0.4946, Train Accuracy: 82.37%
# Epoch [72/200], Test Loss: 0.6182, Test Accuracy: 79.21%
# Epoch 73
# -------------------------------
# Epoch [73/200], Train Loss: 0.4912, Train Accuracy: 82.63%
# Epoch [73/200], Test Loss: 0.5857, Test Accuracy: 80.20%
# Epoch 74
# -------------------------------
# Epoch [74/200], Train Loss: 0.4903, Train Accuracy: 82.56%
# Epoch [74/200], Test Loss: 0.5902, Test Accuracy: 80.04%
# Epoch 75
# -------------------------------
# Epoch [75/200], Train Loss: 0.4820, Train Accuracy: 82.89%
# Epoch [75/200], Test Loss: 0.6013, Test Accuracy: 79.77%
# Epoch 76
# -------------------------------
# Epoch [76/200], Train Loss: 0.4790, Train Accuracy: 82.90%
# Epoch [76/200], Test Loss: 0.5746, Test Accuracy: 80.43%
# Epoch 77
# -------------------------------
# Epoch [77/200], Train Loss: 0.4693, Train Accuracy: 83.34%
# Epoch [77/200], Test Loss: 0.6101, Test Accuracy: 79.87%
# Epoch 78
# -------------------------------
# Epoch [78/200], Train Loss: 0.4673, Train Accuracy: 83.42%
# Epoch [78/200], Test Loss: 0.6029, Test Accuracy: 79.85%
# Epoch 79
# -------------------------------
# Epoch [79/200], Train Loss: 0.4600, Train Accuracy: 83.65%
# Epoch [79/200], Test Loss: 0.6124, Test Accuracy: 79.69%
# Epoch 80
# -------------------------------
# Epoch [80/200], Train Loss: 0.4578, Train Accuracy: 83.72%
# Epoch [80/200], Test Loss: 0.5815, Test Accuracy: 80.87%
# Epoch 81
# -------------------------------
# Epoch [81/200], Train Loss: 0.4562, Train Accuracy: 83.86%
# Epoch [81/200], Test Loss: 0.5732, Test Accuracy: 80.76%
# Epoch 82
# -------------------------------
# Epoch [82/200], Train Loss: 0.4505, Train Accuracy: 84.03%
# Epoch [82/200], Test Loss: 0.5774, Test Accuracy: 80.61%
# Epoch 83
# -------------------------------
# Epoch [83/200], Train Loss: 0.4472, Train Accuracy: 84.16%
# Epoch [83/200], Test Loss: 0.5816, Test Accuracy: 80.30%
# Epoch 84
# -------------------------------
# Epoch [84/200], Train Loss: 0.4438, Train Accuracy: 84.17%
# Epoch [84/200], Test Loss: 0.5802, Test Accuracy: 80.63%
# Epoch 85
# -------------------------------
# Epoch [85/200], Train Loss: 0.4409, Train Accuracy: 84.31%
# Epoch [85/200], Test Loss: 0.5789, Test Accuracy: 80.50%
# Epoch 86
# -------------------------------
# Epoch [86/200], Train Loss: 0.4312, Train Accuracy: 84.61%
# Epoch [86/200], Test Loss: 0.5885, Test Accuracy: 80.36%
# Epoch 87
# -------------------------------
# Epoch [87/200], Train Loss: 0.4279, Train Accuracy: 84.81%
# Epoch [87/200], Test Loss: 0.5846, Test Accuracy: 80.92%
# Epoch 88
# -------------------------------
# Epoch [88/200], Train Loss: 0.4240, Train Accuracy: 84.88%
# Epoch [88/200], Test Loss: 0.5895, Test Accuracy: 80.38%
# Epoch 89
# -------------------------------
# Epoch [89/200], Train Loss: 0.4204, Train Accuracy: 85.07%
# Epoch [89/200], Test Loss: 0.5682, Test Accuracy: 81.02%
# Epoch 90
# -------------------------------
# Epoch [90/200], Train Loss: 0.4155, Train Accuracy: 85.21%
# Epoch [90/200], Test Loss: 0.6150, Test Accuracy: 80.07%
# Epoch 91
# -------------------------------
# Epoch [91/200], Train Loss: 0.4124, Train Accuracy: 85.24%
# Epoch [91/200], Test Loss: 0.6037, Test Accuracy: 80.31%
# Epoch 92
# -------------------------------
# Epoch [92/200], Train Loss: 0.4100, Train Accuracy: 85.33%
# Epoch [92/200], Test Loss: 0.5772, Test Accuracy: 81.59%
# Epoch 93
# -------------------------------
# Epoch [93/200], Train Loss: 0.4014, Train Accuracy: 85.78%
# Epoch [93/200], Test Loss: 0.5866, Test Accuracy: 81.03%
# Epoch 94
# -------------------------------
# Epoch [94/200], Train Loss: 0.4009, Train Accuracy: 85.93%
# Epoch [94/200], Test Loss: 0.5957, Test Accuracy: 80.98%
# Epoch 95
# -------------------------------
# Epoch [95/200], Train Loss: 0.4021, Train Accuracy: 85.71%
# Epoch [95/200], Test Loss: 0.5972, Test Accuracy: 80.70%
# Epoch 96
# -------------------------------
# Epoch [96/200], Train Loss: 0.3959, Train Accuracy: 85.85%
# Epoch [96/200], Test Loss: 0.5745, Test Accuracy: 81.25%
# Epoch 97
# -------------------------------
# Epoch [97/200], Train Loss: 0.3954, Train Accuracy: 85.77%
# Epoch [97/200], Test Loss: 0.5780, Test Accuracy: 80.92%
# Epoch 98
# -------------------------------
# Epoch [98/200], Train Loss: 0.3901, Train Accuracy: 86.17%
# Epoch [98/200], Test Loss: 0.5627, Test Accuracy: 81.66%
# Epoch 99
# -------------------------------
# Epoch [99/200], Train Loss: 0.3881, Train Accuracy: 86.08%
# Epoch [99/200], Test Loss: 0.5791, Test Accuracy: 80.86%
# Epoch 100
# -------------------------------
# Epoch [100/200], Train Loss: 0.3785, Train Accuracy: 86.64%
# Epoch [100/200], Test Loss: 0.5926, Test Accuracy: 80.78%
# Epoch 101
# -------------------------------
# Epoch [101/200], Train Loss: 0.3801, Train Accuracy: 86.34%
# Epoch [101/200], Test Loss: 0.5890, Test Accuracy: 80.85%
# Epoch 102
# -------------------------------
# Epoch [102/200], Train Loss: 0.3786, Train Accuracy: 86.43%
# Epoch [102/200], Test Loss: 0.6187, Test Accuracy: 80.05%
# Epoch 103
# -------------------------------
# Epoch [103/200], Train Loss: 0.3719, Train Accuracy: 86.75%
# Epoch [103/200], Test Loss: 0.6090, Test Accuracy: 81.07%
# Epoch 104
# -------------------------------
# Epoch [104/200], Train Loss: 0.3740, Train Accuracy: 86.70%
# Epoch [104/200], Test Loss: 0.5780, Test Accuracy: 81.27%
# Epoch 105
# -------------------------------
# Epoch [105/200], Train Loss: 0.3704, Train Accuracy: 86.94%
# Epoch [105/200], Test Loss: 0.5820, Test Accuracy: 81.57%
# Epoch 106
# -------------------------------
# Epoch [106/200], Train Loss: 0.3709, Train Accuracy: 86.67%
# Epoch [106/200], Test Loss: 0.6161, Test Accuracy: 80.86%
# Epoch 107
# -------------------------------
# Epoch [107/200], Train Loss: 0.3679, Train Accuracy: 86.87%
# Epoch [107/200], Test Loss: 0.5879, Test Accuracy: 81.70%
# Epoch 108
# -------------------------------
# Epoch [108/200], Train Loss: 0.3562, Train Accuracy: 87.41%
# Epoch [108/200], Test Loss: 0.5838, Test Accuracy: 82.09%
# Epoch 109
# -------------------------------
# Epoch [109/200], Train Loss: 0.3549, Train Accuracy: 87.47%
# Epoch [109/200], Test Loss: 0.5564, Test Accuracy: 82.43%
# Epoch 110
# -------------------------------
# Epoch [110/200], Train Loss: 0.3510, Train Accuracy: 87.55%
# Epoch [110/200], Test Loss: 0.5952, Test Accuracy: 81.73%
# Epoch 111
# -------------------------------
# Epoch [111/200], Train Loss: 0.3454, Train Accuracy: 87.78%
# Epoch [111/200], Test Loss: 0.6052, Test Accuracy: 80.98%
# Epoch 112
# -------------------------------
# Epoch [112/200], Train Loss: 0.3402, Train Accuracy: 87.86%
# Epoch [112/200], Test Loss: 0.6046, Test Accuracy: 80.74%
# Epoch 113
# -------------------------------
# Epoch [113/200], Train Loss: 0.3398, Train Accuracy: 87.71%
# Epoch [113/200], Test Loss: 0.6190, Test Accuracy: 80.54%
# Epoch 114
# -------------------------------
# Epoch [114/200], Train Loss: 0.3359, Train Accuracy: 87.97%
# Epoch [114/200], Test Loss: 0.6326, Test Accuracy: 80.65%
# Epoch 115
# -------------------------------
# Epoch [115/200], Train Loss: 0.3286, Train Accuracy: 88.18%
# Epoch [115/200], Test Loss: 0.5818, Test Accuracy: 81.78%
# Epoch 116
# -------------------------------
# Epoch [116/200], Train Loss: 0.3317, Train Accuracy: 88.23%
# Epoch [116/200], Test Loss: 0.5887, Test Accuracy: 81.73%
# Epoch 117
# -------------------------------
# Epoch [117/200], Train Loss: 0.3277, Train Accuracy: 88.30%
# Epoch [117/200], Test Loss: 0.6187, Test Accuracy: 80.97%
# Epoch 118
# -------------------------------
# Epoch [118/200], Train Loss: 0.3322, Train Accuracy: 88.25%
# Epoch [118/200], Test Loss: 0.5644, Test Accuracy: 82.40%
# Epoch 119
# -------------------------------
# Epoch [119/200], Train Loss: 0.3273, Train Accuracy: 88.46%
# Epoch [119/200], Test Loss: 0.5903, Test Accuracy: 81.92%
# Epoch 120
# -------------------------------
# Epoch [120/200], Train Loss: 0.3184, Train Accuracy: 88.41%
# Epoch [120/200], Test Loss: 0.6108, Test Accuracy: 81.39%
# Epoch 121
# -------------------------------
# Epoch [121/200], Train Loss: 0.3202, Train Accuracy: 88.55%
# Epoch [121/200], Test Loss: 0.5947, Test Accuracy: 81.53%
# Epoch 122
# -------------------------------
# Epoch [122/200], Train Loss: 0.3106, Train Accuracy: 88.83%
# Epoch [122/200], Test Loss: 0.5948, Test Accuracy: 81.90%
# Epoch 123
# -------------------------------
# Epoch [123/200], Train Loss: 0.3105, Train Accuracy: 89.00%
# Epoch [123/200], Test Loss: 0.5833, Test Accuracy: 82.39%
# Epoch 124
# -------------------------------
# Epoch [124/200], Train Loss: 0.3087, Train Accuracy: 89.06%
# Epoch [124/200], Test Loss: 0.5948, Test Accuracy: 81.81%
# Epoch 125
# -------------------------------
# Epoch [125/200], Train Loss: 0.3060, Train Accuracy: 89.07%
# Epoch [125/200], Test Loss: 0.5841, Test Accuracy: 82.28%
# Epoch 126
# -------------------------------
# Epoch [126/200], Train Loss: 0.2999, Train Accuracy: 89.31%
# Epoch [126/200], Test Loss: 0.5889, Test Accuracy: 82.31%
# Epoch 127
# -------------------------------
# Epoch [127/200], Train Loss: 0.2985, Train Accuracy: 89.24%
# Epoch [127/200], Test Loss: 0.5941, Test Accuracy: 81.81%
# Epoch 128
# -------------------------------
# Epoch [128/200], Train Loss: 0.2977, Train Accuracy: 89.36%
# Epoch [128/200], Test Loss: 0.6078, Test Accuracy: 81.63%
# Epoch 129
# -------------------------------
# Epoch [129/200], Train Loss: 0.2982, Train Accuracy: 89.40%
# Epoch [129/200], Test Loss: 0.6234, Test Accuracy: 81.49%
# Epoch 130
# -------------------------------
# Epoch [130/200], Train Loss: 0.2917, Train Accuracy: 89.63%
# Epoch [130/200], Test Loss: 0.5990, Test Accuracy: 82.06%
# Epoch 131
# -------------------------------
# Epoch [131/200], Train Loss: 0.2858, Train Accuracy: 89.84%
# Epoch [131/200], Test Loss: 0.6231, Test Accuracy: 81.79%
# Epoch 132
# -------------------------------
# Epoch [132/200], Train Loss: 0.2930, Train Accuracy: 89.50%
# Epoch [132/200], Test Loss: 0.6266, Test Accuracy: 81.74%
# Epoch 133
# -------------------------------
# Epoch [133/200], Train Loss: 0.2895, Train Accuracy: 89.57%
# Epoch [133/200], Test Loss: 0.6185, Test Accuracy: 81.93%
# Epoch 134
# -------------------------------
# Epoch [134/200], Train Loss: 0.2838, Train Accuracy: 89.91%
# Epoch [134/200], Test Loss: 0.6457, Test Accuracy: 81.55%
# Epoch 135
# -------------------------------
# Epoch [135/200], Train Loss: 0.2847, Train Accuracy: 89.90%
# Epoch [135/200], Test Loss: 0.6177, Test Accuracy: 82.11%
# Epoch 136
# -------------------------------
# Epoch [136/200], Train Loss: 0.2794, Train Accuracy: 89.92%
# Epoch [136/200], Test Loss: 0.6471, Test Accuracy: 81.30%
# Epoch 137
# -------------------------------
# Epoch [137/200], Train Loss: 0.2814, Train Accuracy: 89.84%
# Epoch [137/200], Test Loss: 0.5937, Test Accuracy: 82.48%
# Epoch 138
# -------------------------------
# Epoch [138/200], Train Loss: 0.2802, Train Accuracy: 90.03%
# Epoch [138/200], Test Loss: 0.6868, Test Accuracy: 80.94%
# Epoch 139
# -------------------------------
# Epoch [139/200], Train Loss: 0.2715, Train Accuracy: 90.17%
# Epoch [139/200], Test Loss: 0.6167, Test Accuracy: 81.40%
# Epoch 140
# -------------------------------
# Epoch [140/200], Train Loss: 0.2741, Train Accuracy: 90.16%
# Epoch [140/200], Test Loss: 0.6223, Test Accuracy: 82.16%
# Epoch 141
# -------------------------------
# Epoch [141/200], Train Loss: 0.2693, Train Accuracy: 90.15%
# Epoch [141/200], Test Loss: 0.6519, Test Accuracy: 81.66%
# Epoch 142
# -------------------------------
# Epoch [142/200], Train Loss: 0.2659, Train Accuracy: 90.52%
# Epoch [142/200], Test Loss: 0.6182, Test Accuracy: 82.31%
# Epoch 143
# -------------------------------
# Epoch [143/200], Train Loss: 0.2654, Train Accuracy: 90.44%
# Epoch [143/200], Test Loss: 0.6619, Test Accuracy: 81.61%
# Epoch 144
# -------------------------------
# Epoch [144/200], Train Loss: 0.2601, Train Accuracy: 90.75%
# Epoch [144/200], Test Loss: 0.6476, Test Accuracy: 81.23%
# Epoch 145
# -------------------------------
# Epoch [145/200], Train Loss: 0.2573, Train Accuracy: 90.78%
# Epoch [145/200], Test Loss: 0.6360, Test Accuracy: 82.03%
# Epoch 146
# -------------------------------
# Epoch [146/200], Train Loss: 0.2551, Train Accuracy: 90.83%
# Epoch [146/200], Test Loss: 0.6164, Test Accuracy: 82.28%
# Epoch 147
# -------------------------------
# Epoch [147/200], Train Loss: 0.2545, Train Accuracy: 90.98%
# Epoch [147/200], Test Loss: 0.6538, Test Accuracy: 82.00%
# Epoch 148
# -------------------------------
# Epoch [148/200], Train Loss: 0.2526, Train Accuracy: 91.02%
# Epoch [148/200], Test Loss: 0.6215, Test Accuracy: 81.99%
# Epoch 149
# -------------------------------
# Epoch [149/200], Train Loss: 0.2530, Train Accuracy: 90.96%
# Epoch [149/200], Test Loss: 0.6695, Test Accuracy: 81.80%
# Epoch 150
# -------------------------------
# Epoch [150/200], Train Loss: 0.2552, Train Accuracy: 90.85%
# Epoch [150/200], Test Loss: 0.6281, Test Accuracy: 81.89%
# Epoch 151
# -------------------------------
# Epoch [151/200], Train Loss: 0.2447, Train Accuracy: 91.30%
# Epoch [151/200], Test Loss: 0.6295, Test Accuracy: 82.81%
# Epoch 152
# -------------------------------
# Epoch [152/200], Train Loss: 0.2449, Train Accuracy: 91.19%
# Epoch [152/200], Test Loss: 0.6390, Test Accuracy: 81.66%
# Epoch 153
# -------------------------------
# Epoch [153/200], Train Loss: 0.2435, Train Accuracy: 91.33%
# Epoch [153/200], Test Loss: 0.6628, Test Accuracy: 81.40%
# Epoch 154
# -------------------------------
# Epoch [154/200], Train Loss: 0.2381, Train Accuracy: 91.37%
# Epoch [154/200], Test Loss: 0.6780, Test Accuracy: 81.52%
# Epoch 155
# -------------------------------
# Epoch [155/200], Train Loss: 0.2401, Train Accuracy: 91.36%
# Epoch [155/200], Test Loss: 0.6445, Test Accuracy: 81.80%
# Epoch 156
# -------------------------------
# Epoch [156/200], Train Loss: 0.2323, Train Accuracy: 91.67%
# Epoch [156/200], Test Loss: 0.6619, Test Accuracy: 82.10%
# Epoch 157
# -------------------------------
# Epoch [157/200], Train Loss: 0.2347, Train Accuracy: 91.60%
# Epoch [157/200], Test Loss: 0.6496, Test Accuracy: 82.19%
# Epoch 158
# -------------------------------
# Epoch [158/200], Train Loss: 0.2312, Train Accuracy: 91.84%
# Epoch [158/200], Test Loss: 0.6544, Test Accuracy: 82.27%
# Epoch 159
# -------------------------------
# Epoch [159/200], Train Loss: 0.2314, Train Accuracy: 91.67%
# Epoch [159/200], Test Loss: 0.6566, Test Accuracy: 81.84%
# Epoch 160
# -------------------------------
# Epoch [160/200], Train Loss: 0.2274, Train Accuracy: 91.81%
# Epoch [160/200], Test Loss: 0.6604, Test Accuracy: 81.72%
# Epoch 161
# -------------------------------
# Epoch [161/200], Train Loss: 0.2274, Train Accuracy: 91.81%
# Epoch [161/200], Test Loss: 0.6606, Test Accuracy: 82.06%
# Epoch 162
# -------------------------------
# Epoch [162/200], Train Loss: 0.2240, Train Accuracy: 91.99%
# Epoch [162/200], Test Loss: 0.6563, Test Accuracy: 82.08%
# Epoch 163
# -------------------------------
# Epoch [163/200], Train Loss: 0.2339, Train Accuracy: 91.66%
# Epoch [163/200], Test Loss: 0.6638, Test Accuracy: 82.19%
# Epoch 164
# -------------------------------
# Epoch [164/200], Train Loss: 0.2207, Train Accuracy: 92.10%
# Epoch [164/200], Test Loss: 0.6874, Test Accuracy: 81.53%
# Epoch 165
# -------------------------------
# Epoch [165/200], Train Loss: 0.2222, Train Accuracy: 91.97%
# Epoch [165/200], Test Loss: 0.6584, Test Accuracy: 82.19%
# Epoch 166
# -------------------------------
# Epoch [166/200], Train Loss: 0.2198, Train Accuracy: 92.12%
# Epoch [166/200], Test Loss: 0.6538, Test Accuracy: 82.43%
# Epoch 167
# -------------------------------
# Epoch [167/200], Train Loss: 0.2170, Train Accuracy: 92.24%
# Epoch [167/200], Test Loss: 0.6705, Test Accuracy: 82.18%
# Epoch 168
# -------------------------------
# Epoch [168/200], Train Loss: 0.2141, Train Accuracy: 92.26%
# Epoch [168/200], Test Loss: 0.6592, Test Accuracy: 82.61%
# Epoch 169
# -------------------------------
# Epoch [169/200], Train Loss: 0.2121, Train Accuracy: 92.35%
# Epoch [169/200], Test Loss: 0.6982, Test Accuracy: 81.74%
# Epoch 170
# -------------------------------
# Epoch [170/200], Train Loss: 0.2111, Train Accuracy: 92.39%
# Epoch [170/200], Test Loss: 0.6710, Test Accuracy: 82.04%
# Epoch 171
# -------------------------------
# Epoch [171/200], Train Loss: 0.2104, Train Accuracy: 92.54%
# Epoch [171/200], Test Loss: 0.6882, Test Accuracy: 81.75%
# Epoch 172
# -------------------------------
# Epoch [172/200], Train Loss: 0.2074, Train Accuracy: 92.72%
# Epoch [172/200], Test Loss: 0.6749, Test Accuracy: 82.77%
# Epoch 173
# -------------------------------
# Epoch [173/200], Train Loss: 0.2067, Train Accuracy: 92.52%
# Epoch [173/200], Test Loss: 0.6478, Test Accuracy: 82.80%
# Epoch 174
# -------------------------------
# Epoch [174/200], Train Loss: 0.2056, Train Accuracy: 92.65%
# Epoch [174/200], Test Loss: 0.7411, Test Accuracy: 81.51%
# Epoch 175
# -------------------------------
# Epoch [175/200], Train Loss: 0.2020, Train Accuracy: 92.85%
# Epoch [175/200], Test Loss: 0.6983, Test Accuracy: 81.89%
# Epoch 176
# -------------------------------
# Epoch [176/200], Train Loss: 0.1979, Train Accuracy: 92.90%
# Epoch [176/200], Test Loss: 0.6890, Test Accuracy: 82.01%
# Epoch 177
# -------------------------------
# Epoch [177/200], Train Loss: 0.2000, Train Accuracy: 92.83%
# Epoch [177/200], Test Loss: 0.6921, Test Accuracy: 82.44%
# Epoch 178
# -------------------------------
# Epoch [178/200], Train Loss: 0.1959, Train Accuracy: 93.01%
# Epoch [178/200], Test Loss: 0.6786, Test Accuracy: 82.92%
# Epoch 179
# -------------------------------
# Epoch [179/200], Train Loss: 0.1949, Train Accuracy: 93.05%
# Epoch [179/200], Test Loss: 0.6758, Test Accuracy: 82.42%
# Epoch 180
# -------------------------------
# Epoch [180/200], Train Loss: 0.1909, Train Accuracy: 93.12%
# Epoch [180/200], Test Loss: 0.7705, Test Accuracy: 81.77%
# Epoch 181
# -------------------------------
# Epoch [181/200], Train Loss: 0.1953, Train Accuracy: 92.91%
# Epoch [181/200], Test Loss: 0.7128, Test Accuracy: 81.97%
# Epoch 182
# -------------------------------
# Epoch [182/200], Train Loss: 0.1951, Train Accuracy: 93.07%
# Epoch [182/200], Test Loss: 0.6788, Test Accuracy: 82.47%
# Epoch 183
# -------------------------------
# Epoch [183/200], Train Loss: 0.1892, Train Accuracy: 93.15%
# Epoch [183/200], Test Loss: 0.6966, Test Accuracy: 82.37%
# Epoch 184
# -------------------------------
# Epoch [184/200], Train Loss: 0.1874, Train Accuracy: 93.27%
# Epoch [184/200], Test Loss: 0.7056, Test Accuracy: 82.23%
# Epoch 185
# -------------------------------
# Epoch [185/200], Train Loss: 0.1919, Train Accuracy: 93.08%
# Epoch [185/200], Test Loss: 0.6919, Test Accuracy: 82.65%
# Epoch 186
# -------------------------------
# Epoch [186/200], Train Loss: 0.1862, Train Accuracy: 93.29%
# Epoch [186/200], Test Loss: 0.6980, Test Accuracy: 82.84%
# Epoch 187
# -------------------------------
# Epoch [187/200], Train Loss: 0.1869, Train Accuracy: 93.31%
# Epoch [187/200], Test Loss: 0.7242, Test Accuracy: 81.72%
# Epoch 188
# -------------------------------
# Epoch [188/200], Train Loss: 0.1881, Train Accuracy: 93.32%
# Epoch [188/200], Test Loss: 0.6905, Test Accuracy: 82.62%
# Epoch 189
# -------------------------------
# Epoch [189/200], Train Loss: 0.1804, Train Accuracy: 93.62%
# Epoch [189/200], Test Loss: 0.7233, Test Accuracy: 82.00%
# Epoch 190
# -------------------------------
# Epoch [190/200], Train Loss: 0.1813, Train Accuracy: 93.55%
# Epoch [190/200], Test Loss: 0.7282, Test Accuracy: 82.38%
# Epoch 191
# -------------------------------
# Epoch [191/200], Train Loss: 0.1761, Train Accuracy: 93.73%
# Epoch [191/200], Test Loss: 0.6925, Test Accuracy: 82.67%
# Epoch 192
# -------------------------------
# Epoch [192/200], Train Loss: 0.1807, Train Accuracy: 93.38%
# Epoch [192/200], Test Loss: 0.7471, Test Accuracy: 81.74%
# Epoch 193
# -------------------------------
# Epoch [193/200], Train Loss: 0.1781, Train Accuracy: 93.60%
# Epoch [193/200], Test Loss: 0.7551, Test Accuracy: 81.59%
# Epoch 194
# -------------------------------
# Epoch [194/200], Train Loss: 0.1730, Train Accuracy: 93.69%
# Epoch [194/200], Test Loss: 0.7076, Test Accuracy: 82.12%
# Epoch 195
# -------------------------------
# Epoch [195/200], Train Loss: 0.1737, Train Accuracy: 93.71%
# Epoch [195/200], Test Loss: 0.7697, Test Accuracy: 81.20%
# Epoch 196
# -------------------------------
# Epoch [196/200], Train Loss: 0.1727, Train Accuracy: 93.83%
# Epoch [196/200], Test Loss: 0.7221, Test Accuracy: 82.18%
# Epoch 197
# -------------------------------
# Epoch [197/200], Train Loss: 0.1687, Train Accuracy: 93.95%
# Epoch [197/200], Test Loss: 0.7383, Test Accuracy: 81.92%
# Epoch 198
# -------------------------------
# Epoch [198/200], Train Loss: 0.1703, Train Accuracy: 93.94%
# Epoch [198/200], Test Loss: 0.7400, Test Accuracy: 82.44%
# Epoch 199
# -------------------------------
# Epoch [199/200], Train Loss: 0.1694, Train Accuracy: 93.89%
# Epoch [199/200], Test Loss: 0.7551, Test Accuracy: 82.39%
# Epoch 200
# -------------------------------
# Epoch [200/200], Train Loss: 0.1679, Train Accuracy: 93.92%
# Epoch [200/200], Test Loss: 0.7230, Test Accuracy: 82.09%
# Finished Training

# %%
# fc1出力の256の特徴量を得る
# 中間層の特徴ベクトルの可視化 
net.eval()
all_features = []
all_labels = []
selected_batch_indices = random.sample(range(len(testloader)), 10)
with torch.no_grad():
    for i, data in enumerate(testloader):
        if i  in selected_batch_indices:  # 10バッチのみ使用 
            images, labels = data[0], data[1]
            # images, labels = data['image'], data['label']
            images = images.to(device)
            output, features = net(images, return_feat=True)
            features = features.cpu().numpy()
            all_features.append(features)
            all_labels.append(labels.cpu().numpy())

all_features = np.concatenate(all_features, axis=0)
all_labels = np.concatenate(all_labels, axis=0)

pca = PCA(n_components=2)
principal_components = pca.fit_transform(all_features.reshape(all_features.shape[0], -1)) # 3D特徴マップを2Dに変換

plt.figure(figsize=(8, 6))
colors = plt.cm.get_cmap('tab10', len(classes)) # または plt.cm.get_cmap('Set1', len(classes)) など

for i in range(len(classes)):
    indices = np.where(all_labels == i)[0]
    plt.scatter(principal_components[indices, 0], principal_components[indices, 1],
                label=classes[i], alpha=0.6, c=[colors(i)])
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Intermediate Layer Features')
plt.legend()
plt.grid(True)
plt.savefig(os.path.join(save_dir, 'pca.png'))
plt.close()


if apply_attention:

    # テストデータからランダムなサンプルを選択
    num_samples_to_visualize = 5
    indices = random.sample(range(len(testset)), num_samples_to_visualize)
    for index in indices:
        img, label = testset[index][0], testset[index][1]
        # img, label = testset[index]['image'], testset[index]['label']
        original_img = img.clone() # 可視化用にオリジナルのテンソルを保持
        class_name = classes[label]
        print(f"Visualizing top-down attention for sample with label: {class_name}")
        save_path = os.path.join(save_dir, f'vis_{index}.png')
        visualize_attention_on_image(device, net, img, original_img, classes, save_path)
# Out:
# /tmp/ipykernel_10610/892776553.py:25: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap('tab10', len(classes)) # または plt.cm.get_cmap('Set1', len(classes)) など
# Visualizing top-down attention for sample with label: horse
# Visualizing top-down attention for sample with label: horse
# Visualizing top-down attention for sample with label: frog
# Visualizing top-down attention for sample with label: cat
# Visualizing top-down attention for sample with label: ship
